# %% [markdown]
#      爬取的是新浪财经《中国年轻人正带领国家走向危机？》评论区的全部评论,并对其内容进行分析，创建用户画像，分析评论用户的地域分布、设备偏好、热度等信息。

# %% [markdown]
# # 确认目标

# %% [markdown]
# - 首先点开文章[《中国年轻人正带领国家走向危机？》](http://finance.sina.com.cn/stock/usstock/c/2018-08-07/doc-ihhkuskt2879316.shtml)，拉到评论区，点击“查看全部XXXX条评论”，在新的页面处，一直下滑就可以一直加载出评论数据。
# - 打开检查模式，依次点击,network-all-preview，点击 "network" >> 点"All" >> 多次点击加载评论>>观察name中重复加载的内容，
# - 并结合“previw”，确定下前者就是爬虫入口的 url，基本信息如下：
#     - Request URL:http://comment.sina.com.cn/page/info?version=1&format=json&channel=cj&newsid=comos-hhkuskt2879316&group=0&compress=0&ie=utf-8&oe=utf-8&page=1&page_size=10&t_size=3&h_size=3&thread=1&uid=unlogin_user&callback=jsonp_1589204387553&_=1589204387553
#     - Request Method:GET
#     - Status Code:200 ok
#     - Remote Address:39.156.6.179:80
#     - Referrer Policy:unsafe-url
# - 多次加载评论，观察Request URL的变化可以看出，仅参数`page=1`和`=jsonp_1589204387553&_=1589204387553`在变化；容易得出page代表页数，`page_size=10`代表10个评论为1页；
# - `jsonp_1589204387553&_=1589204387553`中的数字为时间戳，通过以下代码可转化为标准时间：

# %%
import time
commentTime = 1589204387553 # 13 位，单位ms，一般是 10 位，单位s。
print(commentTime)
print(int(time.time()))
print(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(commentTime/1000)))
# Out:
# 1589204387553
# 1589285429
# 2020-05-11 21:39:47

# %% [markdown]
# # 爬取数据
# - 获取到URL后，先尝试获取第一页数据

# %%
import time
import requests
import json
page = 1
time_stamp = int(time.time()*1000)
url = 'http://comment.sina.com.cn/page/info?version=1&format=json&channel=cj&newsid=comos-hhkuskt2879316&group=0&compress=0&ie=utf-8&oe=utf-8&page={}&page_size=10&t_size=3&h_size=3&thread=1&uid=unlogin_user&callback=jsonp_{}&_={}'.format(page, time_stamp, time_stamp)
r = requests.get(url).text
print(r)
# Out:
# jsonp_1589285432164({"result": {"status": {"msg": "", "code": 0}, "count": {"thread_show": 6, "qreply": 23404, "qreply_show": 8, "total": 34385, "show": 3886}, "language": "ch", "top_thread": {}, "encoding": "utf-8", "cmntlist": [{"comment_imgs": "", "code": "0", "show_loc": "1", "parent_mid": "0", "news_mid_source": "0", "layer": "0", "rank": "1", "mid": "5D3EDD90-DF59F238-16853C6F4-8C5-8B3", "parent_nick": "", "video": "", "thread2": "", "vote": "0", "uid": "6045288180", "area": "\u6cb3\u5357\u5546\u4e18", "channel_source": "", "content": "\u6211\u4e0d\u77e5\u9053\u4f60\u80fd\u4e0d\u80fd\u5e26\u9886\u56fd\u5bb6\uff0c\u4f46\u662f\u4f60\u5df2\u7ecf\u5728\u5f71\u54cd\u6211\u4e86\u3002", "nick": "\u96f6816\u53f7\u65e5\u8bb0\u672c", "hot": "0", "status_uid": "1746404695", "content_ext": {"reply": 0, "weibourl": "http://weibo.com/1746404695/GtF5bynjh"}, "ip": "223.89.242.56", "media_type": "0", "config": "wb_verified=0&wb_screen_name=\u96f6816\u53f7\u65e5\u8bb0\u672c&wb_cmnt_type=comment_retweeted_status&wb_user_id=6045288180&wb_description=&area=\u6cb3\u5357\u5546\u4e18&wb_parent=&wb_profile_img=http://tvax3.sinaimg.cn/crop.0.0.810.810.50/006B7pC4ly8g4rg4eqihdj30mi0mimyd.jpg&wb_time=2019-07-29 19:50:39&wb_comment_id=4399479186368743", "channel": "cj", "comment_mid": "0", "status": "M_PASS", "openid": "", "newsid_source": "", "parent": "", "status_show": "0", "status_cmnt_mid": "4399479186368743", "is_top": "0", "parent_profile_img": "", "news_mid": "0", "import_type": "wb_url", "newsid": "comos-hhkuskt2879316", "level": "11", "count_layer": "0", "parent_uid": "0", "parent_new": "", "thread_mid": "0", "thread": "", "status2": "", "did": "", "is_agree": "0", "top_desc": "", "against": "1564401040", "check_type": "0", "usertype": "wb", "length": "24", "profile_img": "http://tvax3.sinaimg.cn/crop.0.0.810.810.50/006B7pC4ly8g4rg4eqihdj30mi0mimyd.jpg", "batch_type": "0", "time": "2019-07-29 19:50:41", "login_type": "0", "is_hot": "0", "audio": "", "agree": "1"}, {"comment_imgs": "", "code": "0", "show_loc": "1", "parent_mid": "0", "news_mid_source": "0", "layer": "0", "rank": "0", "mid": "5D12EA21-3AF1A632-DF67A9DD-8C5-974", "parent_nick": "", "video": "", "thread2": "", "vote": "0", "uid": "3748112861", "area": "\u6c5f\u82cf\u5357\u901a", "channel_source": "", "content": "\u4e3a\u5565\u4e09\u5e74\uff1f\u4e24\u5e74\u514d\u589e\u503c\u7a0e", "nick": "\u4e0d\u60f3\u7406\u4f60\u9e2d", "hot": "0", "status_uid": "5632218981", "content_ext": {"reply": 1, "weibourl": "http://weibo.com/5632218981/HAFtJd5rt"}, "ip": "58.241.166.50", "media_type": "0", "config": "wb_verified=0&wb_screen_name=\u4e0d\u60f3\u7406\u4f60\u9e2d&wb_cmnt_type=comment_retweeted_status&wb_user_id=3748112861&wb_description=&area=\u6c5f\u82cf\u5357\u901a&wb_parent=&wb_profile_img=http://tvax4.sinaimg.cn/crop.0.0.750.750.50/df67a9ddly8g054n7mtj3j20ku0ku74x.jpg&wb_time=2019-06-26 11:44:31&wb_comment_id=4387398047598125", "channel": "cj", "comment_mid": "0", "status": "M_PASS", "openid": "", "newsid_source": "", "parent": "", "status_show": "0", "status_cmnt_mid": "4387398047598125", "is_top": "0", "parent_profile_img": "", "news_mid": "0", "import_type": "wb_url", "newsid": "comos-hhkuskt2879316", "level": "8", "count_layer": "0", "parent_uid": "0", "parent_new": "", "thread_mid": "0", "thread": "", "status2": "", "did": "", "is_agree": "0", "top_desc": "", "against": "1561520673", "check_type": "0", "usertype": "wb", "length": "11", "profile_img": "http://tvax4.sinaimg.cn/crop.0.0.750.750.50/df67a9ddly8g054n7mtj3j20ku0ku74x.jpg", "batch_type": "0", "time": "2019-06-26 11:44:33", "login_type": "0", "is_hot": "0", "audio": "", "agree": "0"}, {"comment_imgs": "", "code": "0", "show_loc": "1", "parent_mid": "0", "news_mid_source": "0", "layer": "0", "rank": "0", "mid": "5D12E56A-3D362CFB-4758B853-8C5-86D", "parent_nick": "", "video": "", "thread2": "", "vote": "0", "uid": "1196996691", "area": "\u6cb3\u5357\u6d1b\u9633", "channel_source": "", "content": "\u5e78\u597d\u6211\u4e0d\ ...

# %% [markdown]
# - 从获取的数据可以看出，数据为json格式，需要将其转化为python可以处理的格式，去掉前20个无效字符`jsonp_1589205555068`和最后一个`)`后，剩下的就是我们需要的信息,我们选取第一页的一部分数据打印出来：

# %%
import time
import requests
import json
for page in range(1,2):
    time_stamp = int(time.time()*1000)
    url = 'http://comment.sina.com.cn/page/info?version=1&format=json&channel=cj&newsid=comos-hhkuskt2879316&group=0&compress=0&ie=utf-8&oe=utf-8&page={}&page_size=10&t_size=3&h_size=3&thread=1&uid=unlogin_user&callback=jsonp_{}&_={}'.format(page, time_stamp, time_stamp)
    r = requests.get(url).text
    json_dict = json.loads(r[20:-1])
    cmntlist = json_dict["result"]["cmntlist"]
    for num,cmnt in  enumerate(cmntlist):
        print(num, cmnt['nick'],cmnt['area'], cmnt['ip'], cmnt['time'], cmnt['content'], cmnt['rank']) 
    break
# Out:
# 0 零816号日记本 河南商丘 223.89.242.56 2019-07-29 19:50:41 我不知道你能不能带领国家，但是你已经在影响我了。 1
# 1 不想理你鸭 江苏南通 58.241.166.50 2019-06-26 11:44:33 为啥三年？两年免增值税 0
# 2 托比托 河南洛阳 61.54.44.251 2019-06-26 11:24:26 幸好我不用还房贷，不然一个月2500会让我睡不着觉的。 0
# 3 海棠猫张小宝 甘肃兰州 42.90.91.3 2019-06-26 11:22:46 我房贷每月两千五，三十年。要不你让银行把房子收走，我不买了 0
# 4 影片道具女神水 福建福州 218.85.43.208 2019-06-23 20:22:17 脑子是个好东西，希望你也有 0
# 5 幸福平安快乐53770 山西太原 223.12.236.50 2019-04-09 11:07:24 宝宝，冷静点啊 0
# 6 鲍鲍BOBO新家 广东 223.104.63.98 2018-10-09 07:22:56 上一辈，努力挣钱买房是上一辈的事 下一辈不积谷防饥，是下一辈的事 只要下一辈不厚着脸皮问上一辈要婚房结婚，不理所当然认为房子是父母该送给你们的，就可以了 0
# 7 严家可爱豆 江西南昌 59.63.206.200 2018-08-28 22:05:46 哈哈 0
# 8 顾小慢Catherine 重庆 123.147.248.51 2018-08-28 19:23:37 爸爸妈妈买房，说啃老。自己不买房，说没上进心。不生娃，说是自私。那是因为大部分90后的我们真的不富裕，没法一下子拿出几十百万买房子。这也会被说，为什么不努力工作？[皱眉]要我们怎样？ 10
# 9 顾小慢Catherine 重庆 123.147.248.51 2018-08-28 19:23:25 80后买不起房，90后不想买房。 连交通信息卡都发的信用卡，现在又怪我们借贷过度，没有辛苦攒钱？ 我们努力工作，熬成秃头，辛辛苦苦赚钱想用用智能机，想旅旅游，也错了？不想辛辛苦苦攒钱还房贷，也错了？ 8

# %% [markdown]
# - 接下来就是将所有评论爬取下来，并保存在.csv格式的文件中。由于前期还不能确定哪些数据有用，建议将所有数据都存储起来

# %%
import time
import requests
import json
import pandas as pd
import random
csv_path = 'JobClass/BasicKnowledge/cache/'
save_time = time.strftime("%Y%m%d_%H%M%S", time.localtime(time.time()))
comments = pd.DataFrame(columns = ['page','content'])
comments.to_csv(csv_path+'Sina_Finance_Comments_{}.csv'.format(save_time),mode='a',index= False, header=['page','content'], encoding='utf-8')
for page in range(1,390):
    time_stamp = int(time.time()*1000)
    url = 'http://comment.sina.com.cn/page/info?version=1&format=json&channel=cj&newsid=comos-hhkuskt2879316&group=0&compress=0&ie=utf-8&oe=utf-8&page={}&page_size=10&t_size=3&h_size=3&thread=1&uid=unlogin_user&callback=jsonp_{}&_={}'.format(page, time_stamp, time_stamp)
    try:
        r = requests.get(url).text
        json_dict = json.loads(r[20:-1])
        comments = pd.DataFrame({'page':page,'content':json_dict})
        comments.to_csv(csv_path+'Sina_{}.csv'.format(save_time),mode='a',index= False, header=False, encoding='utf-8')
        print('page:',page)
    except Exception as e:
        print('{}页提取异常:{}'.format(page,e))
        break
    time.sleep(random.randint(0,10)) # 每页随机停0-5秒，作为简单的防反爬的一步
# print('JobClass/BasicKnowledge/cache/Sina_20200512_223120.csv')
# Out:
# JobClass/BasicKnowledge/cache/Sina_20200512_223120.csv

# %% [markdown]
# # 处理数据

# %% [markdown]
# ## 提取有效数据

# %% [markdown]
#     上一节我们获得了该文章的全部评论数据，包括一系列数据，接下来就是选取我们需要的信息，出去无效信息

# %%
import pandas as pd
import ast

raw_data = pd.read_csv('JobClass/BasicKnowledge/cache/Sina_20200512_223120_1.csv')
# print(raw_data)
list_content = raw_data['content']
p = 1

# filtered_data =(columns={'nick','area','ip','time','content','agree','usertype'})
filtered_list = []
for page_content in list_content:
    try:
        page_dict = ast.literal_eval(page_content)
        cmntlist = page_dict['cmntlist']
    except Exception as e:
        print('{}页解析失败：{}'.format(p,e))
    else:
        for num,cmnt in  enumerate(cmntlist):
            new_data ={
                'page':p,
                'nick':cmnt['nick'],
                'area':cmnt['area'],
                'ip':cmnt['ip'],
                'time':cmnt['time'],
                'content':cmnt['content'],
                'agree':cmnt['agree'],
                'rank':cmnt['rank'],
                'usertype':cmnt['usertype']
                }
            filtered_list.append(new_data)
    p = p + 1
filtered_data = pd.DataFrame(filtered_list,columns=['page','nick','area','ip','time','content','agree','rank','usertype'])
filtered_data.to_csv('JobClass/BasicKnowledge/cache/Sina_20200512_223120_4_filtered_data.csv')
# Out:
# 21页解析失败：'cmntlist'
# 30页解析失败：'cmntlist'
# 41页解析失败：'cmntlist'
# 53页解析失败：'cmntlist'
# 54页解析失败：'cmntlist'
# 61页解析失败：'cmntlist'
# 74页解析失败：'cmntlist'
# 81页解析失败：'cmntlist'
# 91页解析失败：'cmntlist'
# 101页解析失败：'cmntlist'
# 114页解析失败：'cmntlist'
# 121页解析失败：'cmntlist'
# 133页解析失败：'cmntlist'
# 141页解析失败：'cmntlist'
# 142页解析失败：'cmntlist'
# 152页解析失败：'cmntlist'
# 153页解析失败：'cmntlist'
# 161页解析失败：'cmntlist'
# 172页解析失败：'cmntlist'
# 181页解析失败：'cmntlist'
# 192页解析失败：'cmntlist'
# 201页解析失败：'cmntlist'
# 213页解析失败：'cmntlist'
# 221页解析失败：'cmntlist'
# 231页解析失败：'cmntlist'
# 241页解析失败：'cmntlist'
# 252页解析失败：'cmntlist'
# 261页解析失败：'cmntlist'
# 276页解析失败：'cmntlist'
# 281页解析失败：'cmntlist'
# 292页解析失败：'cmntlist'
# 301页解析失败：'cmntlist'
# 312页解析失败：'cmntlist'
# 321页解析失败：'cmntlist'
# 335页解析失败：'cmntlist'
# 341页解析失败：'cmntlist'
# 343页解析失败：'cmntlist'
# 344页解析失败：'cmntlist'
# 345页解析失败：'cmntlist'
# 346页解析失败：'cmntlist'
# 349页解析失败：'cmntlist'
# 360页解析失败：'cmntlist'
# 361页解析失败：'cmntlist'
# 369页解析失败：'cmntlist'
# 370页解析失败：'cmntlist'
# 380页解析失败：'cmntlist'
# 381页解析失败：'cmntlist'
# 382页解析失败：'cmntlist'
#       page      nick  area              ip                 time  \
# 0        1  零816号日记本  河南商丘   223.89.242.56  2019-07-29 19:50:41
# 1        1     不想理你鸭  江苏南通   58.241.166.50  2019-06-26 11:44:33
# 2        1       托比托  河南洛阳    61.54.44.251  2019-06-26 11:24:26
# 3        1    海棠猫张小宝  甘肃兰州      42.90.91.3  2019-06-26 11:22:46
# 4        1   影片道具女神水  福建福州   218.85.43.208  2019-06-23 20:22:17
# ...    ...       ...   ...             ...                  ...
# 2736   306   龙狮子1976  辽宁大连  124.93.197.160  2018-08-07 20:59:45
# 2737   306    特大碗牛肉粉  湖南长沙   42.49.142.166  2018-08-07 20:57:44
# 2738   306     天上一个使   伊拉克    185.20.25.36  2018-08-07 20:56:53
# 2739   306      西峡邪士  广东佛山    14.25.12.254  2018-08-07 20:44:07
# 2740   307   KingHeb  广东深圳    113.87.12.31  2018-08-07 20:29:50
#
#                             content agree rank usertype
# 0          我不知道你能不能带领国家，但是你已经在影响我了。     1    1       wb
# 1                       为啥三年？两年免增值税     0    0       wb
# 2       幸好我不用还房贷，不然一个月2500会让我睡不着觉的。     0    0       wb
# 3     我房贷每月两千五，三十年。要不你让银行把房子收走，我不买了     0    0       wb
# 4                     脑子是个好东西，希望你也有     0    0       wb
# ...                             ...   ...  ...      ...
# 2736                             夸张     0    0       wb
# 2737                          就是这个范     0    0       wb
# 2738                 借贷不怕，关键是能不能还的上     0    0       wb
# 2739                         未来是他们的     1    1       wb
# 2740                           年轻人？     0    0       wb
#
# [2741 rows x 9 columns]

# %% [markdown]
# ## 分析数据

# %% [markdown]
# - 绘制点赞分布图，并打印出前十个点赞高的

# %%
from matplotlib import pyplot as plt
import pandas as pd
filtered_data = pd.read_csv('JobClass/BasicKnowledge/cache/Sina_20200512_223120_4_filtered_data.csv')
plt.figure(1)
plt.plot(filtered_data['agree'])
plt.show()
a = filtered_data.sort_values(['agree'],ascending=False).head(10)['content']
print(a)
# Out:
# 2245                    笑死了，我工作辛苦买不起房子，还不允许我买星巴克 买包 旅游了？？
# 2223                     庞大债务貌似不是什么狗屁智能手机、大牌衣服、星巴克咖啡馆造成的吧
# 2731                                         我日，这锅是硬砸在头上了
# 2586                      不然呢？非要学上一代那样上半辈子卖命挣钱，下半辈子花钱买命吗？
# 2333    开始怪年轻人的消费观念了？银行滥发信用卡，你现在怪我消费观？房价高的离谱，必须贷款买，你告诉...
# 2570                                          你只想让我攒钱买房哦？
# 906                           “你们应该把钱攒着买房 吃馒头咸菜就行了要啥业余活动”
# 1238                                    我可真牛逼 我还想带领人类走向毁灭
# 974                 想要新手机大牌衣服天天星巴克嘛？！！你只要不买房就可以做到啦！！！！！！！
# 2587    现在买房的大部分都是年青人，只是有的人买的起，有的人买不起，都在同一个屋檐下，买不起房怪国家...
# Name: content, dtype: object

# %% [markdown]
# - 统计使用的设备类型及数量

# %%
b = filtered_data.loc[:,'usertype'].value_counts()
print(b)
b.plot(kind='bar')
# Out:
# wb          2710
# pc            17
# wap            6
# palmnews       4
# Name: usertype, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei'] # 步骤一（替换sans-serif字体）
fig = plt.figure(figsize=(8,60))
c = filtered_data.loc[:,'area'].value_counts()
print(c)
c.plot(kind='barh')
# Out:
# 北京        237
# 上海        200
# 广东广州      126
# 四川成都      107
# 广东深圳       91
#          ...
# 美国俄勒冈州      1
# 黑龙江伊春       1
# 江西景德镇       1
# 吉林松原        1
# 海南三亚        1
# Name: area, Length: 311, dtype: int64

# %%
# 随便练习
import time
import requests
import json
page = 21
time_stamp = int(time.time()*1000)
url = 'http://comment.sina.com.cn/page/info?version=1&format=json&channel=cj&newsid=comos-hhkuskt2879316&group=0&compress=0&ie=utf-8&oe=utf-8&page={}&page_size=10&t_size=3&h_size=3&thread=1&uid=unlogin_user&callback=jsonp_{}&_={}'.format(page, time_stamp, time_stamp)
r = requests.get(url).text
json_dict = json.loads(r[20:-1])
cmntlist = json_dict["result"]["cmntlist"]
for num,cmnt in  enumerate(cmntlist):
    print(num, cmnt['nick'],cmnt['area'], cmnt['ip'], cmnt['time'], cmnt['content'], cmnt['rank'])
# Out:
# 0 李鸡肋 广东广州 119.34.206.33 2018-08-09 09:04:20 老是写这些无脑文章怕是故意找骂吧 0
# 1 SKY-蓝天 广东广州 119.130.120.47 2018-08-09 09:03:44 还要脸不？ 1
# 2 Max的旧货店 安徽合肥 36.60.129.107 2018-08-09 09:01:16 真是恶心 0
# 3 垃圾筐与电影院 四川成都 222.212.88.71 2018-08-09 08:55:27 有个研究显示，70后智商是持续下降的。 0
# 4 刚马甲 上海 211.136.126.10 2018-08-09 08:49:28 呵 商品经济炒作挖坑哄年轻人消费生孩子还不是你们上一辈正在做的 1
# 5 大着肚子做B超 江苏常州 223.104.145.254 2018-08-09 08:42:45 哈哈哈。把锅甩给年轻人了。厉害 0
# 6 amie是佳妹儿 四川成都 110.188.59.203 2018-08-09 08:41:21 但直觉告诉我之后钱会越来越是钱，勒紧裤腰带多存点吧 0
# 7 Just-sosoul 河南开封 61.158.146.87 2018-08-09 08:37:36 我是来看评论的 0
# 8 陶慕白zz 北京 223.104.254.16 2018-08-09 08:35:20 我去年买了个登山包超耐磨[二哈][二哈][二哈] 0
# 9 群租房mvp 广东广州 112.96.195.200 2018-08-09 08:32:03 当初不是你们让我们掏空3个钱包买房的？[费解][费解][费解][费解] 0
